# %% [markdown]
# # Filter Kolom Dataset Banjir
#
# Memfilter dataset untuk menyisakan hanya kolom yang dibutuhkan untuk analisis

# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('data_banjir_joined.csv')

print("Dataset loaded successfully!")
print("=" * 60)
print(f"Shape: {df.shape}")
print(f"Columns: {len(df.columns)}")
print("\nAll columns in dataset:")
for i, col in enumerate(df.columns, 1):
    print(f"{i:3d}. {col}")
# Out:
# Dataset loaded successfully!
# ============================================================
# Shape: (18047, 40)
# Columns: 40
#
# All columns in dataset:
#   1. NAME_2
#   2. NAME_3
#   3. avg_rainfall
#   4. max_rainfall
#   5. avg_temperature
#   6. elevation
#   7. landcover_class
#   8. ndvi
#   9. slope
#  10. soil_moisture
#  11. year
#  12. month
#  13. banjir
#  14. lat
#  15. long
#  16. map_image
#  17. NAME_3_clean
#  18. kecamatan_key_banjir
#  19. objectid
#  20. kode_kec_spatial
#  21. nama_prop
#  22. nama_kab
#  23. nama_kec
#  24. jumlah_penduduk
#  25. kepadatan_penduduk
#  26. jumlah_kk
#  27. luas_wilayah
#  28. pertumbuhan_2022
#  29. pertumbuhan_2021
#  30. pertumbuhan_2020
#  31. perpindahan_pddk
#  32. jumlah_desa
#  33. jumlah_kelurahan
#  34. perdagangan
#  35. nelayan
#  36. wiraswasta
#  37. tidak_blm_sekolah
#  38. slta
#  39. s1
#  40. kecamatan_key_kecamatan
# C:\Users\admin\AppData\Local\Temp\ipykernel_7772\1531449502.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data_banjir_joined.csv')

# %% [markdown]
# ## 2. Filter Kolom yang Dibutuhkan

# %%
selected_columns = [
    'kabupaten_kota',
    'kecamatan',
    'avg_rainfall',
    'max_rainfall',
    'avg_temperature',
    'elevation',
    'landcover_class',
    'ndvi',
    'slope',
    'soil_moisture',
    'year',
    'month',
    'banjir',
    'lat',
    'long',
    'jumlah_penduduk'
]

print("Kolom yang akan disimpan:")
print("=" * 60)
for i, col in enumerate(selected_columns, 1):
    print(f"{i:3d}. {col}")

print(f"\nTotal: {len(selected_columns)} kolom")
# Out:
# Kolom yang akan disimpan:
# ============================================================
#   1. kabupaten_kota
#   2. kecamatan
#   3. avg_rainfall
#   4. max_rainfall
#   5. avg_temperature
#   6. elevation
#   7. landcover_class
#   8. ndvi
#   9. slope
#  10. soil_moisture
#  11. year
#  12. month
#  13. banjir
#  14. lat
#  15. long
#  16. jumlah_penduduk
#
# Total: 16 kolom

# %%
print("Validasi kolom:")
print("=" * 60)

missing_columns = []
available_columns = []

for col in selected_columns:
    if col in df.columns:
        available_columns.append(col)
        print(f"✓ {col}")
        print(f"OK {col}")
        missing_columns.append(col)
        print(f"✗ {col} - TIDAK DITEMUKAN")
        print(f"NO {col} - TIDAK DITEMUKAN")
if missing_columns:
    print(f"\n⚠️  WARNING: {len(missing_columns)} kolom tidak ditemukan:")
    print(f"\nWARNING: {len(missing_columns)} kolom tidak ditemukan:")
    print(f"  - {col}")
else:
    print(f"\n✅ Semua {len(selected_columns)} kolom ditemukan!")
# Out:
# Validasi kolom:
# ============================================================
# ✓ avg_rainfall
# OK avg_rainfall
# ✗ avg_rainfall - TIDAK DITEMUKAN
# NO avg_rainfall - TIDAK DITEMUKAN
# ✓ max_rainfall
# OK max_rainfall
# ✗ max_rainfall - TIDAK DITEMUKAN
# NO max_rainfall - TIDAK DITEMUKAN
# ✓ avg_temperature
# OK avg_temperature
# ✗ avg_temperature - TIDAK DITEMUKAN
# NO avg_temperature - TIDAK DITEMUKAN
# ✓ elevation
# OK elevation
# ✗ elevation - TIDAK DITEMUKAN
# NO elevation - TIDAK DITEMUKAN
# ✓ landcover_class
# OK landcover_class
# ✗ landcover_class - TIDAK DITEMUKAN
# NO landcover_class - TIDAK DITEMUKAN
# ✓ ndvi
# OK ndvi
# ✗ ndvi - TIDAK DITEMUKAN
# NO ndvi - TIDAK DITEMUKAN
# ✓ slope
# OK slope
# ✗ slope - TIDAK DITEMUKAN
# NO slope - TIDAK DITEMUKAN
# ✓ soil_moisture
# OK soil_moisture
# ✗ soil_moisture - TIDAK DITEMUKAN
# NO soil_moisture - TIDAK DITEMUKAN
# ✓ year
# OK year
# ✗ year - TIDAK DITEMUKAN
# NO year - TIDAK DITEMUKAN
# ✓ month
# OK month
# ✗ month - TIDAK DITEMUKAN
# NO month - TIDAK DITEMUKAN
# ✓ banjir
# OK banjir
# ✗ banjir - TIDAK DITEMUKAN
# NO banjir - TIDAK DITEMUKAN
# ✓ lat
# OK lat
# ✗ lat - TIDAK DITEMUKAN
# NO lat - TIDAK DITEMUKAN
# ✓ long
# OK long
# ✗ long - TIDAK DITEMUKAN
# NO long - TIDAK DITEMUKAN
# ✓ jumlah_penduduk
# OK jumlah_penduduk
# ✗ jumlah_penduduk - TIDAK DITEMUKAN
# NO jumlah_penduduk - TIDAK DITEMUKAN
#
# ⚠️  WARNING: 14 kolom tidak ditemukan:
#
# WARNING: 14 kolom tidak ditemukan:
#   - jumlah_penduduk

# %%
df_filtered = df[available_columns].copy()

print("Dataset setelah filtering:")
print("=" * 60)
print(f"Shape sebelum: {df.shape}")
print(f"Shape sesudah: {df_filtered.shape}")
print(f"Kolom dikurangi: {df.shape[1]} → {df_filtered.shape[1]} ({df.shape[1] - df_filtered.shape[1]} kolom dihapus)")

print("\nSample data (5 baris pertama):")
print(df_filtered.head())
# Out:
# Dataset setelah filtering:
# ============================================================
# Shape sebelum: (18047, 40)
# Shape sesudah: (18047, 14)
# Kolom dikurangi: 40 → 14 (26 kolom dihapus)
#
# Sample data (5 baris pertama):
#    avg_rainfall  max_rainfall  avg_temperature  elevation landcover_class  \
# 0        64.775       124.032            28.76    501.913      Tree cover
# 1        68.241       128.949            32.89    133.589        Built-up
# 2        56.423        92.324            29.93    765.651      Tree cover
# 3        60.034        98.129            30.02    143.845      Tree cover
# 4        66.380       133.877            30.27    212.619      Tree cover
#
#     ndvi  slope  soil_moisture  year  month  banjir     lat      long  \
# 0  0.564  5.001         39.583  2020      1       1 -6.5917  106.9020
# 1  0.429  0.293         40.414  2020      1       1 -6.4774  106.7927
# 2  0.513  4.954         39.662  2020      1       0 -6.7366  106.8660
# 3  0.652  2.107         39.014  2020      1       0 -6.5273  107.1371
# 4  0.569  1.340         39.658  2020      1       0 -6.5742  106.6980
#
#    jumlah_penduduk
# 0         121972.0
# 1         266481.0
# 2         138901.0
# 3          54478.0
# 4         175400.0

# %% [markdown]
# ## 2.5 Hapus Data yang Tidak Ter-join (Tanpa jumlah_penduduk)

# %%
print("Statistik sebelum pembersihan:")
print("=" * 60)
print(f"Total baris: {len(df_filtered):,}")
print(f"Baris dengan jumlah_penduduk: {df_filtered['jumlah_penduduk'].notna().sum():,}")
print(f"Baris tanpa jumlah_penduduk: {df_filtered['jumlah_penduduk'].isna().sum():,}")
print(f"Persentase missing: {(df_filtered['jumlah_penduduk'].isna().sum() / len(df_filtered) * 100):.2f}%")

df_filtered_clean = df_filtered[df_filtered['jumlah_penduduk'].notna()].copy()

print("\n" + "=" * 60)
print("Statistik setelah pembersihan:")
print("=" * 60)
print(f"Total baris: {len(df_filtered_clean):,}")
print(f"Baris dihapus: {len(df_filtered) - len(df_filtered_clean):,}")
print(f"Baris tersisa: {(len(df_filtered_clean) / len(df_filtered) * 100):.2f}%")

print("\n✅ Data yang tidak ter-join berhasil dihapus!")
print("\nData yang tidak ter-join berhasil dihapus!")
# Out:
# Statistik sebelum pembersihan:
# ============================================================
# Total baris: 18,047
# Baris dengan jumlah_penduduk: 18,040
# Baris tanpa jumlah_penduduk: 7
# Persentase missing: 0.04%
#
# ============================================================
# Statistik setelah pembersihan:
# ============================================================
# Total baris: 18,040
# Baris dihapus: 7
# Baris tersisa: 99.96%
#
# ✅ Data yang tidak ter-join berhasil dihapus!
#
# Data yang tidak ter-join berhasil dihapus!

# %% [markdown]
# ## 3. Cek Data Quality (Setelah Pembersihan)

# %%
print("Missing Values:")
print("=" * 60)
missing_stats = df_filtered_clean.isnull().sum()
missing_percent = (missing_stats / len(df_filtered_clean) * 100).round(2)

for col in df_filtered_clean.columns:
    missing_count = missing_stats[col]
    missing_pct = missing_percent[col]
    if missing_count > 0:
        print(f"⚠️  {col:25s}: {missing_count:6d} ({missing_pct:5.2f}%)")
        print(f"WARNING {col:25s}: {missing_count:6d} ({missing_pct:5.2f}%)")
        print(f"✓  {col:25s}: {missing_count:6d} ({missing_pct:5.2f}%)")
        print(f"OK     {col:25s}: {missing_count:6d} ({missing_pct:5.2f}%)")
print(f"\nTotal missing values: {df_filtered_clean.isnull().sum().sum():,}")
# Out:
# Missing Values:
# ============================================================
#
# Total missing values: 0

# %%
print("Dataset Info:")
print("=" * 60)
df_filtered_clean.info()

print("\n" + "=" * 60)
print("Summary Statistics:")
print("=" * 60)
print(df_filtered_clean.describe())
# Out:
# Dataset Info:
# ============================================================
# <class 'pandas.core.frame.DataFrame'>
# Index: 18040 entries, 0 to 18046
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   avg_rainfall     18040 non-null  float64
#  1   max_rainfall     18040 non-null  float64
#  2   avg_temperature  18040 non-null  float64
#  3   elevation        18040 non-null  float64
#  4   landcover_class  18040 non-null  object
#  5   ndvi             18040 non-null  float64
#  6   slope            18040 non-null  float64
#  7   soil_moisture    18040 non-null  float64
#  8   year             18040 non-null  int64
#  9   month            18040 non-null  int64
#  10  banjir           18040 non-null  int64
#  11  lat              18040 non-null  float64
#  12  long             18040 non-null  float64
#  13  jumlah_penduduk  18040 non-null  float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 2.1+ MB
#
# ============================================================
# Summary Statistics:
# ============================================================
#        avg_rainfall  max_rainfall  avg_temperature     elevation  \
# count  18040.000000  18040.000000     18040.000000  18040.000000
# mean      44.967323     83.671850        32.184179    155.943438
# std       25.483127     44.372316         4.676834    256.459310
# min        0.525000      0.858000        11.490000      0.000000
# 25%       25.168250     52.811500        28.510000     13.259000
# 50%       42.279500     77.836000        31.666667     43.009000
# 75%       61.001750    108.638250        36.218125    164.336000
# max      222.600000    386.707000        43.830000   1814.735000
#
#                ndvi         slope  soil_moisture          year         month  \
# count  18040.000000  18040.000000   18040.000000  18040.000000  18040.000000
# mean       0.491803      1.389861      36.307384   2022.100831      6.329878
# std        0.181190      2.163852       3.911884      1.390926      3.680200
# min        0.082000      0.000000      13.210000   2020.000000      1.000000
# 25%        0.346000      0.127000      34.331000   2021.000000      3.000000
# 50%        0.488000      0.278000      37.386000   2022.000000      6.000000
# 75%        0.643000      1.743000      38.758000   2023.000000     10.000000
# max        0.891000     12.015000      42.898000   2024.000000     12.000000
#
#              banjir           lat          long  jumlah_penduduk
# count  18040.000000  18040.000000  18040.000000     18040.000000
# mean       0.438193     -5.144154    108.069218    128526.011530
# std        0.496179      3.042400      5.241536    103984.478584
# min        0.000000    -10.855200     95.241700      1452.000000
# 25%        0.000000     -6.521700    106.631100     52590.000000
# 50%        0.000000     -6.251600    106.850900    108418.000000
# 75%        1.000000     -6.087800    107.853100    170342.000000
# max        1.000000      5.586300    140.652000    596213.000000

# %% [markdown]
# ## 4. Export ke File CSV Baru

# %%
output_filename = 'data_banjir_filtered.csv'

try:
    df_filtered_clean.to_csv(output_filename, index=False, encoding='utf-8-sig')
    
    print("DATA BERHASIL DISIMPAN!")
    print("=" * 60)
    print(f"File: {output_filename}")
    print(f"Total rows: {len(df_filtered_clean):,}")
    print(f"Total columns: {len(df_filtered_clean.columns)}")
    
    import os
    file_size = os.path.getsize(output_filename) / (1024 * 1024)
    print(f"File size: {file_size:.2f} MB")
    
    original_size = os.path.getsize('data_banjir_joined_clean.csv') / (1024 * 1024)
    reduction = ((original_size - file_size) / original_size * 100)
    print(f"\nPengurangan ukuran: {original_size:.2f} MB -> {file_size:.2f} MB ({reduction:.1f}% lebih kecil)")
    
    print("\nKOLOM YANG DISIMPAN:")
    for i, col in enumerate(df_filtered_clean.columns, 1):
        print(f"  {i:2d}. {col}")
    
    print(f"\nData tidak ter-join (tanpa jumlah_penduduk) telah dihapus")
    print(f"Baris awal: {len(df):,} -> Baris akhir: {len(df_filtered_clean):,}")
    
except Exception as e:
    print(f"Error saat menyimpan file: {e}")
# Out:
# DATA BERHASIL DISIMPAN!
# ============================================================
# File: data_banjir_filtered.csv
# Total rows: 18,040
# Total columns: 14
# File size: 1.56 MB
#
# Pengurangan ukuran: 3.87 MB -> 1.56 MB (59.6% lebih kecil)
#
# KOLOM YANG DISIMPAN:
#    1. avg_rainfall
#    2. max_rainfall
#    3. avg_temperature
#    4. elevation
#    5. landcover_class
#    6. ndvi
#    7. slope
#    8. soil_moisture
#    9. year
#   10. month
#   11. banjir
#   12. lat
#   13. long
#   14. jumlah_penduduk
#
# Data tidak ter-join (tanpa jumlah_penduduk) telah dihapus
# Baris awal: 18,047 -> Baris akhir: 18,040
